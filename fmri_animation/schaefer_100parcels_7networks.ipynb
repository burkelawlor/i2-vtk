# %%
import os
os.chdir('/Users/burkelawlor/Repos/fmri-animation')

import pandas as pd
import numpy as np

# %%
networks_df = pd.read_csv('data/Schaefer2018_100Parcels_7Networks_order.txt', sep='\t', names=['label', 'full_name', 'x', 'y', 'z', 't'])

full_names = networks_df.full_name.str.split('_')
networks_df.insert(3, 'network',  full_names.str[2:-1].str[0])
# networks_df.insert(3, 'LR', full_names.str[1])
# networks_df.insert(4, 'number',  full_names.str[-1])

display(networks_df)
# Out:
#     label                    full_name    x  network   y    z  t
# 0       1           7Networks_LH_Vis_1  120      Vis  18  131  0
# 1       2           7Networks_LH_Vis_2  120      Vis  18  132  0
# 2       3           7Networks_LH_Vis_3  120      Vis  18  133  0
# 3       4           7Networks_LH_Vis_4  120      Vis  18  135  0
# 4       5           7Networks_LH_Vis_5  120      Vis  18  136  0
# ..    ...                          ...  ...      ...  ..  ... ..
# 95     96  7Networks_RH_Default_PFCm_1  208  Default  62   79  0
# 96     97  7Networks_RH_Default_PFCm_2  208  Default  62   80  0
# 97     98  7Networks_RH_Default_PFCm_3  208  Default  62   81  0
# 98     99   7Networks_RH_Default_PCC_1  208  Default  62   78  0
# 99    100   7Networks_RH_Default_PCC_2  208  Default  62   82  0
#
# [100 rows x 7 columns]

# %%
networks_df[networks_df.network == 'Default']
# Out:
#     label                    full_name    x  network   y   z  t
# 37     38  7Networks_LH_Default_Temp_1  205  Default  62  80  0
# 38     39  7Networks_LH_Default_Temp_2  205  Default  62  81  0
# 39     40  7Networks_LH_Default_Temp_3  205  Default  62  82  0
# 40     41  7Networks_LH_Default_Temp_4  205  Default  62  83  0
# 41     42   7Networks_LH_Default_PFC_1  205  Default  63  76  0
# 42     43   7Networks_LH_Default_PFC_2  205  Default  63  77  0
# 43     44   7Networks_LH_Default_PFC_3  205  Default  63  79  0
# 44     45   7Networks_LH_Default_PFC_4  205  Default  63  80  0
# 45     46   7Networks_LH_Default_PFC_5  205  Default  63  81  0
# 46     47   7Networks_LH_Default_PFC_6  205  Default  63  82  0
# 47     48   7Networks_LH_Default_PFC_7  205  Default  63  83  0
# 48     49   7Networks_LH_Default_PCC_1  205  Default  63  84  0
# 49     50   7Networks_LH_Default_PCC_2  205  Default  63  85  0
# 89     90   7Networks_RH_Default_Par_1  209  Default  62  78  0
# 90     91  7Networks_RH_Default_Temp_1  209  Default  61  79  0
# 91     92  7Networks_RH_Default_Temp_2  209  Default  61  80  0
# 92     93  7Networks_RH_Default_Temp_3  209  Default  61  81  0
# 93     94  7Networks_RH_Default_PFCv_1  209  Default  61  78  0
# 94     95  7Networks_RH_Default_PFCv_2  209  Default  61  82  0
# 95     96  7Networks_RH_Default_PFCm_1  208  Default  62  79  0
# 96     97  7Networks_RH_Default_PFCm_2  208  Default  62  80  0
# 97     98  7Networks_RH_Default_PFCm_3  208  Default  62  81  0
# 98     99   7Networks_RH_Default_PCC_1  208  Default  62  78  0
# 99    100   7Networks_RH_Default_PCC_2  208  Default  62  82  0
